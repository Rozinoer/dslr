# %% [markdown]
# # Datascience X Logistic Regression

# %% [markdown]
# # V.1 Data Analysis

# %%
import pandas as pd
df = pd.read_csv('dataset_train.csv')
df.describe()
# Out:
#             Index     Arithmancy    Astronomy    Herbology  \
# count  1600.00000    1566.000000  1568.000000  1567.000000
# mean    799.50000   49634.570243    39.797131     1.141020
# std     462.02453   16679.806036   520.298268     5.219682
# min       0.00000  -24370.000000  -966.740546   -10.295663
# 25%     399.75000   38511.500000  -489.551387    -4.308182
# 50%     799.50000   49013.500000   260.289446     3.469012
# 75%    1199.25000   60811.250000   524.771949     5.419183
# max    1599.00000  104956.000000  1016.211940    11.612895
#
#        Defense Against the Dark Arts   Divination  Muggle Studies  \
# count                    1569.000000  1561.000000     1565.000000
# mean                       -0.387863     3.153910     -224.589915
# std                         5.212794     4.155301      486.344840
# min                       -10.162119    -8.727000    -1086.496835
# 25%                        -5.259095     3.099000     -577.580096
# ...

# %%
import dslr.describe as ds
ds.main('dataset_train.csv')
# Out:
#              Index     Arithmancy    Astronomy    Herbology  Defense Against the Dark Arts   Divination  Muggle Studies  Ancient Runes  History of Magic  Transfiguration      Potions  Care of Magical Creatures       Charms       Flying
# count  1600.000000    1566.000000  1568.000000  1567.000000                    1569.000000  1561.000000     1565.000000    1565.000000       1557.000000      1566.000000  1570.000000                1560.000000  1600.000000  1600.000000
# mean    799.500000   49634.570243    39.797131     1.141020                      -0.387863     3.153910     -224.589915     495.747970          2.963095      1030.096946     5.950373                  -0.053427  -243.374409    21.958012
# std     462.024530   16679.806036   520.298268     5.219682                       5.212794     4.155301      486.344840     106.285165          4.425775        44.125116     3.147854                   0.971457     8.783640    97.631602
# ...

# %% [markdown]
# # V.2 Data Visualization
# ## V.2.1 Histogram

# %%
import dslr.histogram as hist
hist.histogram('dataset_train.csv')

# %% [markdown]
# ## V.2.2 Scatter plot

# %%
import dslr.scatter_plot as sp

sp.scatter(5,6)

# %% [markdown]
# ## V.2.3 Pair plot

# %%
import dslr.pair_plot as pp

pp.pair_plot()

# %% [markdown]
# # V.3 Logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib as plot
import matplotlib.pyplot as plot
import seaborn as sns
import dslr.logreg_train as lt

# %%
df = pd.read_csv('dataset_train.csv')
df.head()
# Out:
#    Index Hogwarts House First Name  Last Name    Birthday Best Hand  \
# 0      0      Ravenclaw     Tamara        Hsu  2000-03-30      Left
# 1      1      Slytherin      Erich    Paredes  1999-10-14     Right
# 2      2      Ravenclaw   Stephany      Braun  1999-11-03      Left
# 3      3     Gryffindor      Vesta  Mcmichael  2000-08-19      Left
# 4      4     Gryffindor     Gaston      Gibbs  1998-09-27      Left
#
#    Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# 0     58384.0 -487.886086   5.727180                       4.878861
# 1     67239.0 -552.060507  -5.987446                       5.520605
# 2     23702.0 -366.076117   7.725017                       3.660761
# 3     32667.0  697.742809  -6.497214                      -6.977428
# 4     60158.0  436.775204  -7.820623                            NaN
#
#    Divination  Muggle Studies  Ancient Runes  History of Magic  \
# 0       4.722      272.035831     532.484226          5.231058
# ...

# %% [markdown]
# ### Train with Gradient Descent

# %%
lt.mainProcess(path='dataset_train.csv', bonus=False, size=0)
# Out:
# Trainning Ravenclaw
# Trainning Slytherin
# Trainning Gryffindor
# Trainning Hufflepuff

# %% [markdown]
# ### Train with Stochatic Gradient Descent

# %%
lt.mainProcess(path='dataset_train.csv', bonus=True, size=0)
# Out:
# Trainning Ravenclaw
# Trainning Slytherin
# Trainning Gryffindor
# Trainning Hufflepuff

# %% [markdown]
# ### Train with Mini-Batch Gradient Descent

# %%
lt.mainProcess(path='dataset_train.csv', bonus=True, size=32)
# Out:
# Trainning Ravenclaw
# Trainning Slytherin
# Trainning Gryffindor
# Trainning Hufflepuff

# %% [markdown]
# # Predict

# %%
import dslr.logreg_predict as lp
lp.mainProcess(df_path='dataset_test.csv', thetas_path='thetas.csv')

# %%
result = pd.read_csv('Houses.csv')
result.head()
# Out:
#   Hogwarts House
# 0      Slytherin
# 1     Gryffindor
# 2      Ravenclaw
# 3     Gryffindor
# 4      Ravenclaw
